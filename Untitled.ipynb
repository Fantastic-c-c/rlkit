# %%
# %load comparison_metarl.py
# from rllab.viskit import core
import matplotlib.pyplot as plt
# %matplotlib inline
from plot_utils_mb import *
import os
import csv
import json

plt.style.use('ggplot')
#plt.rc('font', family='Times New Roman')
import matplotlib
matplotlib.use('TkAgg')
#matplotlib.font_manager._rebuild()


SMALL_SIZE = 20
MEDIUM_SIZE = 22
BIGGER_SIZE = 26
LINEWIDTH = 3

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title



prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
COLORS = dict(ours=colors.pop(0))
LEGEND_ORDER = {'ours': 0, 'promp': 1, 'maml': 2, 'rl2': 3,}




class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self


def load_exps_data(exp_folder_paths, disable_variant=False):
    exps = []
    for exp_folder_path in exp_folder_paths:
        exps += [x[0] for x in os.walk(exp_folder_path)]
    exps_data = []
    for exp in exps:
        try:
            exp_path = exp
            params_json_path = os.path.join(exp_path, "params.json")
            variant_json_path = os.path.join(exp_path, "variant.json")
            progress_csv_path = os.path.join(exp_path, "progress.csv")
            progress = load_progress(progress_csv_path)
            if disable_variant:
                params = load_params(params_json_path)
            else:
                try:
                    params = load_params(variant_json_path)
                except IOError:
                    params = load_params(params_json_path)
            exps_data.append(AttrDict(
                progress=progress, params=params, flat_params=flatten_dict(params)))
        except IOError as e:
            print(e)
    return exps_data

def load_progress(progress_csv_path):
    print("Reading %s" % progress_csv_path)
    entries = dict()
    with open(progress_csv_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            for k, v in row.items():
                if k not in entries:
                    entries[k] = []
                try:
                    entries[k].append(float(v))
                except:
                    entries[k].append(0.)
    entries = dict([(k, np.array(v)) for k, v in entries.items()])
    return entries

def flatten_dict(d):
    flat_params = dict()
    for k, v in d.items():
        if isinstance(v, dict):
            v = flatten_dict(v)
            for subk, subv in flatten_dict(v).items():
                flat_params[k + "." + subk] = subv
        else:
            flat_params[k] = v
    return flat_params


def load_params(params_json_path):
    with open(params_json_path, 'r') as f:
        data = json.loads(f.read())
        if "args_data" in data:
            del data["args_data"]
        if "exp_name" not in data:
            data["exp_name"] = params_json_path.split("/")[-2]
    return data


def sorting_legend(label):
    return LEGEND_ORDER[label]


def get_color(label):
    if label not in COLORS.keys():
        COLORS[label] = colors.pop(0)
    return COLORS[label]


def plot_from_exps(exp_data,
                   filters={},
                   remove=False,
                   split_figures_by=None,
                   split_plots_by=None,
                   x_key='n_timesteps',
                   y_key=None,
                   sup_y_key=None,
                   plot_name='./bad-models.png',
                   subfigure_titles=None,
                   plot_labels=None,
                   x_label=None,
                   y_label=None,
                   fontsize=20,
                   num_rows=1,
                   x_limits=None,
                   y_limits=None,
                   report_max_performance=False,
                   log_scale=False,
                   round_x=None,
                   ):

    exp_data = filter(exp_data, filters=filters, remove=remove)
    print(len(exp_data))
    exps_per_plot = group_by(exp_data, group_by_key=split_figures_by)
    print(exps_per_plot)
    num_columns = len(exps_per_plot.keys())
    print(num_columns)
    # assert num_columns % num_rows == 0
    num_columns = num_columns // num_rows
    fig, axarr = plt.subplots(num_rows, num_columns, figsize=(20, 8))
    fig.tight_layout(pad=4.0, w_pad=1.5, h_pad=3, rect=[0, 0, 1, 1])

    # iterate over subfigures
    for i, (default_plot_title, plot_exps) in enumerate(sorted(exps_per_plot.items())):
        plots_in_figure_exps = group_by(plot_exps, split_plots_by)
        subfigure_title = subfigure_titles[i] if subfigure_titles else default_plot_title
        r, c = i//num_columns, i%num_columns
        axarr[r, c].set_title(subfigure_title)
        axarr[r, c].xaxis.set_major_locator(plt.MaxNLocator(5))
        axarr[r, c].ticklabel_format(style='sci', axis='x', scilimits=(0, 0))

        # iterate over plots in figure
        y_max_mean = -1e10
        y_axis_min = 1e10
        y_axis_max = -1e10
        for j, default_label in enumerate(sorted(plots_in_figure_exps, key=sorting_legend)):
            exps = plots_in_figure_exps[default_label]
            x, y_mean, y_std = prepare_data_for_plot(exps, x_key=x_key, y_key=y_key, sup_y_key=sup_y_key, round_x=round_x)
            if y_mean.shape[0] == 0:
                continue
            label = plot_labels[j] if plot_labels else default_label
            _label = label if i == 0 else "__nolabel__"
            if log_scale:
                axarr[r, c].semilogx(x, y_mean, label=_label, linewidth=LINEWIDTH, color=get_color(label))
            else:
                axarr[r, c].plot(x, y_mean, label=_label, linewidth=LINEWIDTH, color=get_color(label))

            axarr[r, c].fill_between(x, y_mean + y_std, y_mean - y_std, alpha=0.2, color=get_color(label))

            # axis labels
            axarr[r, c].set_xlabel(x_label if x_label else x_key)
            axarr[r, c].set_ylabel(y_label if y_label else y_key)
            if x_limits is not None:
                axarr[r, c].set_xlim(*x_limits)
            if y_limits is not None:
                axarr[r, c].set_ylim(*y_limits)
            else:
                _y_axis_min, _y_axis_max = correct_limit(axarr[r, c], x, y_mean+2*y_std)
                y_axis_max = max(_y_axis_max, y_axis_max)
                y_axis_min = min(_y_axis_min, y_axis_min)
            if max(y_mean) > y_max_mean:
                y_max_mean = max(y_mean)
        if report_max_performance:
            label = 'max' if i == 0 else "__nolabel__"
            axarr[r, c].plot(axarr[r, c].get_xlim(), [y_max_mean]*2, 'k--', label=label)
        if y_limits is None:
            axarr[r, c].set_ylim([y_axis_min, y_axis_max])

    fig.legend(loc='lower center', ncol=4, bbox_transform=plt.gcf().transFigure)
    fig.savefig(plot_name)


########## Add data path here #############
data_path = ['pearl-results']
###########################################
# Out:
# /home/rakelly/miniconda3/envs/rlkit/lib/python3.5/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
data_path = '../pearl-results'

exps_data = load_exps_data([data_path], False)

filter_dict = {'env.$class': 'maml_zoo.envs.mujoco_envs.ant_rand_goal.AntRandGoalEnv'}

plot_from_exps(exps_data,
               remove=True,
               split_figures_by='env.$class',
               split_plots_by='exp_name',
               y_key='train-AverageReturn',
               filters=filter_dict,
               sup_y_key=['Step_1-AverageReturn', 'train-AverageReturn'],
               # subfigure_titles=['HalfCheetah - output_bias_range [0.0, 0.1]',
               #                  'HalfCheetah - output_bias_range [0.0, 0.5]',
               #                  'HalfCheetah - output_bias_range [0.0, 1.0]'],
               # plot_labels=['ME-MPG', 'ME-TRPO'],
               x_label='Time steps',
               y_label='Average return',
               plot_name='./off_policy_meta_rl.pdf',
               num_rows=2,
               x_limits=[0, 5e7],
               # y_limits=[-100, 100],
               report_max_performance=True,
               log_scale=False,
               # round_x=4000,
               )
# Out:
# Reading ../pearl-results/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/progress.csv'
# Reading ../pearl-results/humanoid-rand-direc/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/humanoid-rand-direc/progress.csv'
# Reading ../pearl-results/humanoid-rand-direc/ppo-eval-final-1537417616579/progress.csv
# Reading ../pearl-results/humanoid-rand-direc/ppo-eval-final-1537417634052/progress.csv
# Reading ../pearl-results/humanoid-rand-direc/ppo-humanoid-longer-1537926208434/progress.csv
# Reading ../pearl-results/humanoid-rand-direc/ppo-humanoid-longer-1537926221670/progress.csv
# Reading ../pearl-results/humanoid-rand-direc/ppo-eval-final-1537417643581/progress.csv
# Reading ../pearl-results/humanoid-rand-direc/ppo-eval-final-1537417603275/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/def-def-def-maml-kate-deidre/progress.csv'
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182810986/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182809776/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182803382/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182806236/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182812370/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182807375/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182813656/progress.csv
# Reading ../pearl-results/def-def-def-maml-kate-deidre/def-def-def-maml-kate-deidre-1548182808661/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/def-def-def-promp-kate-deidre/progress.csv'
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182337856/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182344463/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182330927/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182339429/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182341117/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182327567/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182321007/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182342838/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182332581/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182329278/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182325856/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182324390/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182334233/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182335798/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182346077/progress.csv
# Reading ../pearl-results/def-def-def-promp-kate-deidre/def-def-def-promp-kate-deidre-1548182347824/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/walker-rand-params-maml/progress.csv'
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937390473/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937386322/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937539980/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537928160127/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937391812/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537928151044/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937372847/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937529290/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937543012/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937384880/progress.csv
# Reading ../pearl-results/walker-rand-params-maml/trpo-rand-params-longer-1537937380541/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/def-def-promp-kate-deidre/progress.csv'
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127899387/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127882034/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127888310/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127910370/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127904109/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127897763/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127889867/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127892954/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127894475/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127883610/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127905697/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127891469/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127908677/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127902708/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127885246/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127907116/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127901160/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127886741/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127878509/progress.csv
# Reading ../pearl-results/def-def-promp-kate-deidre/def-def-promp-kate-deidre-1548127896097/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/hopper-rand-params-maml/progress.csv'
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937538290/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937393174/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937383493/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537928161338/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937541436/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537928162730/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937394581/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937544501/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937381909/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937387654/progress.csv
# Reading ../pearl-results/hopper-rand-params-maml/trpo-rand-params-longer-1537937389100/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/def-def-maml-kate-deidre/progress.csv'
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127935066/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127950141/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127959517/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127938851/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127943336/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127944606/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127940056/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127957122/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127952353/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127958371/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127949107/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127946771/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127945697/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127937898/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127941080/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127954859/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127953658/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127942115/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127951221/progress.csv
# Reading ../pearl-results/def-def-maml-kate-deidre/def-def-maml-kate-deidre-1548127947940/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/humanoid-rand-direc-maml/progress.csv'
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936647456/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936645960/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936632785/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936636046/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-1537922689017/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-1537922692122/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-1537922681592/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936641659/progress.csv
# Reading ../pearl-results/humanoid-rand-direc-maml/trpo-humanoid-longer-2-1537936640156/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/def-def-rl2-kate-deidre/progress.csv'
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548196236546/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100715963/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100695275/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100698639/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100684820/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100685910/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100688349/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100709290/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100689616/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100690828/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548196237502/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100710437/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100711440/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100713632/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100706901/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100697483/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100703355/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100696281/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100714808/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100701157/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100705811/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100704576/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100686971/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100699901/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100708041/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100681700/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100712486/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100694156/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100691814/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548196231317/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100692941/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100702189/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548196235561/progress.csv
# Reading ../pearl-results/def-def-rl2-kate-deidre/def-def-rl2-kate-deidre-1548100717190/progress.csv
# Reading ../pearl-results/walker-rand-params/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/walker-rand-params/progress.csv'
# Reading ../pearl-results/walker-rand-params/ppo-rand-param-tune-1537676897140/progress.csv
# Reading ../pearl-results/walker-rand-params/ppo-rand-param-tune-1537676923498/progress.csv
# Reading ../pearl-results/walker-rand-params/ppo-rand-param-tune-1537676865733/progress.csv
# Reading ../pearl-results/hopper-rand-params/progress.csv
# [Errno 2] No such file or directory: '../pearl-results/hopper-rand-params/progress.csv'
# Reading ../pearl-results/hopper-rand-params/ppo-rand-param-tune-1537676936996/progress.csv
# Reading ../pearl-results/hopper-rand-params/ppo-rand-param-tune-1537676884234/progress.csv
# Reading ../pearl-results/hopper-rand-params/ppo-rand-param-tune-1537676910277/progress.csv
# before filtering 141 exps
# after filtering 141 exps
# 141
# /home/rakelly/rlkit/plot_utils_mb.py:18: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   exps_data_filtered = exps_data_filtered[keep_array]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-fa2e9265aae1> in <module>()
#      23                # y_limits=[-100, 100],
#      24                report_max_performance=True,
# ---> 25                log_scale=False,
#      26                # round_x=4000,
#      27                )
#
# <ipython-input-24-dcff9c0911c9> in plot_from_exps(exp_data, filters, remove, split_figures_by, split_plots_by, x_key, y_key, sup_y_key, plot_name, subfigure_titles, plot_labels, x_label, y_label, fontsize, num_rows, x_limits, y_limits, report_max_performance, log_scale, round_x)
#     147     # assert num_columns % num_rows == 0
#     148     num_columns = num_columns // num_rows
# --> 149     fig, axarr = plt.subplots(num_rows, num_columns, figsize=(20, 8))
#     150     fig.tight_layout(pad=4.0, w_pad=1.5, h_pad=3, rect=[0, 0, 1, 1])
#     151
#
# ~/miniconda3/envs/rlkit/lib/python3.5/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1209
#    1210     # Create first subplot separately, so we can share it if requested
# -> 1211     ax0 = fig.add_subplot(gs[0, 0], **subplot_kw)
#    1212     axarr[0] = ax0
#    1213
#
# ~/miniconda3/envs/rlkit/lib/python3.5/site-packages/matplotlib/gridspec.py in __getitem__(self, key)
#     166                     k2 += ncols
#     167                 if k2 >= ncols or k2 < 0 :
# --> 168                     raise IndexError("index out of range")
#     169                 col1, col2 = k2, k2+1
#     170
#
# IndexError: index out of range
